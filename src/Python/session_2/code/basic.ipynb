# %%
# i need to print something 
x = 30
print("my age = ", x)
# Out:
# my age =  30

# %%
print("hello world")
# Out:
# hello world

# %%
x= True
type(x)
# Out:
# bool

# %%
y = "Depi"
print(type(y))
# Out:
# <class 'str'>

# %%
name= "depi rount 4"
upper_case = name.upper()
print(upper_case)
# Out:
# DEPI ROUNT 4

# %%
lower_case = upper_case.lower()
print(lower_case)
# Out:
# depi rount 4

# %%
name = "welcome into DEPI round 4 with ml"
split_name = name.split()
split_name
# Out:
# ['welcome', 'into', 'DEPI', 'round', '4', 'with', 'ml']

# %%
print(type(split_name))
# Out:
# <class 'list'>

# %%
sent = ' '.join(split_name)
sent
# Out:
# 'welcome into DEPI round 4 with ml'

# %%
print("hello everyone")
print('use\tto print a new line  ')
# Out:
# hello everyone
# use	to print a new line

# %%
len(name)
# Out:
# 33

# %%
"x"  not in "xavier"
# Out:
# False

# %%
s ="welccome to depi"
x = s.find("c")
x
# Out:
# 3

# %%
name ="george"
age= 35
f"my name is {name}, and my age is {age}"
# Out:
# 'my name is george, and my age is 35'
